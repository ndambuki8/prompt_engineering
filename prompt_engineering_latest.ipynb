# %% [markdown]
# ## Prompt Engineering

# %%
import os
from dotenv import load_dotenv

load_dotenv()

#os.environ["HUGGINGFACEHUB_API_TOKEN"]
openai_api_key = os.environ["OPENAI_API_KEY"]

# %% [markdown]
# ### Provide clear instructions

# %%
system_message = """
You are an AI assistant that helps human by generating tutorials given a text.
You will be provided with a text. If the text contains any kind of instructions on how to proceed with something, generate a tutorial in a bullet list.
Otherwise, inform the user tha the text does not contain any instructions.

Text:
"""

instructions = """
To prepare the known sauce from Genova, Italy you can start by toasting the pine nuts to the coarsely 
chop them in a kitchen mortar together with basic and garlic. Then, add half of the oil in the kitchen mprtar and season with salt and pepper.
Finally, transfer the pesto to a bowl and stir in the grated Parmesan cheese.

"""
